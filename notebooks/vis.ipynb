# %%
import numpy as np
import scipy
import sklearn
import matplotlib.pyplot as plt
import librosa
import librosa.display

# %%
bat, sr = librosa.core.load('../data/raw/BatFiles/0001.wav')
print(f'Sample Rate: {sr}')
print(f'Duration: {len(bat) / sr} seconds')
spec = librosa.amplitude_to_db(np.abs(librosa.stft(bat)), ref=np.max)
librosa.display.specshow(spec)
# Out:
# Sample Rate: 22050
# Duration: 3.786077097505669 seconds

# %%
spec.shape
# Out:
# (1025, 219)

# %%
bat, sr = librosa.core.load('./data/ng/boat_outboard_motor.wav')
print(f'Sample Rate: {sr}')
print(f'Duration: {len(bat) / sr} seconds')
spec = librosa.amplitude_to_db(np.abs(librosa.stft(bat)), ref=np.max)
librosa.display.specshow(spec)
# Out:
# Sample Rate: 22050
# Duration: 138.62312925170068 seconds

# %%
spec.shape
# Out:
# (1025, 5971)

# %%
bat, sr = librosa.core.load('./data/car_starting.wav')
print(f'Sample Rate: {sr}')
print(f'Duration: {len(bat) / sr} seconds')
spec = librosa.amplitude_to_db(np.abs(librosa.stft(bat)), ref=np.max)
librosa.display.specshow(spec)
# Out:
# Sample Rate: 22050
# Duration: 4.7772789115646255

# %%
sr
# Out:
# 22050

# %%
flatness = librosa.feature.spectral_flatness(y=bat)

# %%
plt.plot(flatness[0])
